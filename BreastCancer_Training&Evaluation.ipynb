# %% [markdown]
# <a href="https://colab.research.google.com/github/FETIELOVE/s28210_Tutor4/blob/main/BreastCancer_Training%26Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colab Setup

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# #Load and Explore Breast dataset

# %%
data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %% [markdown]
# #Preprocessing the Data

# %%
X= df.drop(columns='target')
y= df['target']
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
pd.DataFrame(X_scaled, columns=X.columns).head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0     1.097064     -2.073335        1.269934   0.984375         1.568466
# 1     1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2     1.579888      0.456187        1.566503   1.558884         0.942210
# 3    -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4     1.750297     -1.151816        1.776573   1.826229         0.280372
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0          3.283515        2.652874             2.532475       2.217515
# 1         -0.487072       -0.023846             0.548144       0.001392
# 2          1.052926        1.363478             2.037231       0.939685
# 3          3.402909        1.915897             1.451707       2.867383
# 4          0.539340        1.371011             1.428493      -0.009560
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %% [markdown]
# #Splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (455, 30) (114, 30) (455,) (114,)

# %% [markdown]
# #Logistic Regression

# %%
log_reg = LogisticRegression()
log_reg.fit(X_train, y_train)
y_pred = log_reg.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
            xticklabels=data.target_names, yticklabels=data.target_names)
plt.title('Logistic Regression Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
print(f"hyperparameters: {log_reg.get_params()}")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"recall: {recall}")
print(f"F1 Score: {f1}")
print(conf_matrix)
# Out:
# hyperparameters: {'C': 1.0, 'class_weight': None, 'dual': False, 'fit_intercept': True, 'intercept_scaling': 1, 'l1_ratio': None, 'max_iter': 100, 'multi_class': 'deprecated', 'n_jobs': None, 'penalty': 'l2', 'random_state': None, 'solver': 'lbfgs', 'tol': 0.0001, 'verbose': 0, 'warm_start': False}
# Accuracy: 0.9736842105263158
# Precision: 0.9737190197716513
# recall: 0.9736842105263158
# F1 Score: 0.973621425014614
# [[41  2]
#  [ 1 70]]

# %% [markdown]
# #Random Forest

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=42)  # You can adjust n_estimators based on the desired number of trees
rf.fit(X_train, y_train)

# Predict on test data
y_pred = rf.predict(X_test)

# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

# Print evaluation metrics
print(f"Random Forest Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")

# Confusion Matrix
conf_matrix_rf = confusion_matrix(y_test, y_pred)

# Plot Confusion Matrix
plt.figure(figsize=(7, 5))
sns.heatmap(conf_matrix_rf, annot=True, fmt='d', cmap='Blues',
            xticklabels=data.target_names, yticklabels=data.target_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix for Random Forest')
plt.show()

# Log the hyperparameters used in the model
print(f"Random Forest Hyperparameters: {rf.get_params()}")
# Out:
# Random Forest Accuracy: 0.96
# Precision: 0.97
# Recall: 0.96
# F1 Score: 0.96
# Random Forest Hyperparameters: {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}

# %% [markdown]
# #SVM

# %%
svm = SVC(kernel='linear', random_state=42)
svm.fit(X_train, y_train)

# Predict on test data
y_pred = svm.predict(X_test)

# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

# Print evaluation metrics
print(f"SVM Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")

# Confusion Matrix
conf_matrix_svm = confusion_matrix(y_test, y_pred)

# Plot Confusion Matrix
plt.figure(figsize=(7, 5))
sns.heatmap(conf_matrix_svm, annot=True, fmt='d', cmap='Blues',
            xticklabels=data.target_names, yticklabels=data.target_names)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix for SVM')
plt.show()

# Log the hyperparameters used in the model
print(f"SVM Hyperparameters: {svm.get_params()}")
# Out:
# SVM Accuracy: 0.96
# Precision: 0.96
# Recall: 0.96
# F1 Score: 0.96
# SVM Hyperparameters: {'C': 1.0, 'break_ties': False, 'cache_size': 200, 'class_weight': None, 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'linear', 'max_iter': -1, 'probability': False, 'random_state': 42, 'shrinking': True, 'tol': 0.001, 'verbose': False}

# %% [markdown]
# #Model Comparison
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Observations and Analysis
# 1. Logistic Regression:
#
#
# *   Strengths:
#
#  - Best accuracy and lowest false negatives, crucial for minimizing missed malignant cases.
#
#  -  Simple and interpretable, making it a great choice for medical diagnostics.
#
# - Limitations:
#  - May struggle with more complex or non-linear patterns compared to Random Forest.
#
# 2. Random Forest:
#
# - Strengths:
#  - Handles non-linear patterns and noise effectively.
#  - Metrics are comparable to Logistic Regression, with high precision (97%) and balanced recall/F1 (96%).
#
# - Limitations:
#  - Slightly higher false positives (3), which could lead to unnecessary follow-ups.
#  - More complex and less interpretable than Logistic Regression.
#
# 3. SVM:
#
# - Strengths:
#  - Performs consistently well, with accuracy, precision, recall, and F1 at 96%.
#  - Suitable for datasets with clear margins of separation between classes.
#
# - Limitations:
#  - Highest false negatives (3), making it less suitable for medical use.
# Computationally more expensive, especially for larger datasets.
#
#
# # Best Model: Logistic Regression
#
# Logistic Regression achieved the highest accuracy (97%), the lowest false negatives (1), and well-balanced metrics (Precision, Recall, and F1 Score all at 97%). This makes it the most reliable and interpretable choice for this breast cancer classification problem.
